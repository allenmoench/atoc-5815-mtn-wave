# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from data_analysis_package.plotting import timeseries_plot as tp

import data_analysis_package.data_download as dd
import data_analysis_package.download_iterator as di
import datetime
import data_analysis_package.run_analysis as ra

import seaborn as sb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 from data_analysis_package.plotting import timeseries_plot
#       6 import data_analysis_package.data_download as dd
#       7 import data_analysis_package.download_iterator as di
#
# ModuleNotFoundError: No module named 'data_analysis_package'
